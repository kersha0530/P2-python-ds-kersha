# %% [markdown]
# # Web Mining and Applied NLP (44-620)
# ## Python Notebooks, Basics, and Data Structures
# # Student Name:
# Kersha Broussard
# # Student Number:
# 919656979
# # GitHub:
# [https://github.com/kersha0530](https://github.com/kersha0530)

# %% [markdown]
# ## Question 10 – Pattern Drawing

# %%
for i in range(1, 5):
    stars = '*' * i
    spaces = ' ' * (8 - 2 * i)
    print(stars + spaces + stars)
# Out:
# *      *
# **    **
# ***  ***
# ********
